# %% [markdown]
# # Example of Reading Images with Pillow

# %%
from PIL import Image
im = Image.open("../images/Pit Pattern I/akh0036-cut-1112629264530.png")
im = im.convert(mode="L") # For some circumstances, when doing im.show() it opens with a other program, than showing here beneath.
im
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x1051F66D0>

# %% [markdown]
# Looping through Pixels:

# %%
raw = im.getdata()
len(raw)
# Out:
# 65536

# %%
im.width * im.height
# Out:
# 65536

# %%
raw[0]

# %% [markdown]
# Below we use our approach with the classes to load the image:

# %%
from ImageData import ImageData, IData, OrigPic
t = OrigPic("../images/Pit Pattern I/akh0036-cut-1112629264530.png")
t.data[0]
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x110267E50>

# %%
print(t)
# Out:
# Hi, i am a IData, but from type EDataType.OrigPic!
# File: ../images/Pit Pattern I/akh0036-cut-1112629264530.png
# Data count: 1
